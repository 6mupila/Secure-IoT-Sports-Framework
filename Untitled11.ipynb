# %% [markdown]
# <a href="https://colab.research.google.com/github/6mupila/thesis-work-/blob/main/Untitled11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install Faker pandas
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 17.3 MB/s eta 0:00:00
# ...

# %%
import pandas as pd

# Load your real dataset
real_data = pd.read_csv("DSL-StrongPasswordData.csv")
display(real_data.head())
# Out:
#   subject  sessionIndex  rep  H.period  DD.period.t  UD.period.t     H.t  \
# 0    s002             1    1    0.1491       0.3979       0.2488  0.1069
# 1    s002             1    2    0.1111       0.3451       0.2340  0.0694
# 2    s002             1    3    0.1328       0.2072       0.0744  0.0731
# 3    s002             1    4    0.1291       0.2515       0.1224  0.1059
# 4    s002             1    5    0.1249       0.2317       0.1068  0.0895
#
#    DD.t.i  UD.t.i     H.i  ...     H.a  DD.a.n  UD.a.n     H.n  DD.n.l  \
# 0  0.1674  0.0605  0.1169  ...  0.1349  0.1484  0.0135  0.0932  0.3515
# 1  0.1283  0.0589  0.0908  ...  0.1412  0.2558  0.1146  0.1146  0.2642
# 2  0.1291  0.0560  0.0821  ...  0.1621  0.2332  0.0711  0.1172  0.2705
# 3  0.2495  0.1436  0.1040  ...  0.1457  0.1629  0.0172  0.0866  0.2341
# 4  0.1676  0.0781  0.0903  ...  0.1312  0.1582  0.0270  0.0884  0.2517
#
#    UD.n.l     H.l  DD.l.Return  UD.l.Return  H.Return
# ...

# %%
from faker import Faker
fake = Faker()

imposter_data = []

for _, row in real_data.iterrows():
    imposter_row = row.copy()
    for col in real_data.columns[3:]:  # Skip metadata columns
        noise = fake.random_number(digits=3, fix_len=True) / 100.0
        noise *= fake.random_element(elements=[-1, 1])
        imposter_row[col] += noise
    imposter_data.append(imposter_row)

imposter_df = pd.DataFrame(imposter_data)

# %%
combined_data = pd.concat([real_data, imposter_df], ignore_index=True)
display(combined_data.head())
# Out:
#   subject  sessionIndex  rep  H.period  DD.period.t  UD.period.t     H.t  \
# 0    s002             1    1    0.1491       0.3979       0.2488  0.1069
# 1    s002             1    2    0.1111       0.3451       0.2340  0.0694
# 2    s002             1    3    0.1328       0.2072       0.0744  0.0731
# 3    s002             1    4    0.1291       0.2515       0.1224  0.1059
# 4    s002             1    5    0.1249       0.2317       0.1068  0.0895
#
#    DD.t.i  UD.t.i     H.i  ...     H.a  DD.a.n  UD.a.n     H.n  DD.n.l  \
# 0  0.1674  0.0605  0.1169  ...  0.1349  0.1484  0.0135  0.0932  0.3515
# 1  0.1283  0.0589  0.0908  ...  0.1412  0.2558  0.1146  0.1146  0.2642
# 2  0.1291  0.0560  0.0821  ...  0.1621  0.2332  0.0711  0.1172  0.2705
# 3  0.2495  0.1436  0.1040  ...  0.1457  0.1629  0.0172  0.0866  0.2341
# 4  0.1676  0.0781  0.0903  ...  0.1312  0.1582  0.0270  0.0884  0.2517
#
#    UD.n.l     H.l  DD.l.Return  UD.l.Return  H.Return
# ...

# %%
combined_data.to_csv("combined_keystroke_data.csv", index=False)
print("Combined dataset saved as 'combined_keystroke_data.csv'")
# Out:
# Combined dataset saved as 'combined_keystroke_data.csv'

# %%
# !head combined_keystroke_data.csv
# Out:
# subject,sessionIndex,rep,H.period,DD.period.t,UD.period.t,H.t,DD.t.i,UD.t.i,H.i,DD.i.e,UD.i.e,H.e,DD.e.five,UD.e.five,H.five,DD.five.Shift.r,UD.five.Shift.r,H.Shift.r,DD.Shift.r.o,UD.Shift.r.o,H.o,DD.o.a,UD.o.a,H.a,DD.a.n,UD.a.n,H.n,DD.n.l,UD.n.l,H.l,DD.l.Return,UD.l.Return,H.Return
# s002,1,1,0.1491,0.3979,0.2488,0.1069,0.1674,0.0605,0.1169,0.2212,0.1043,0.1417,1.1885,1.0468,0.1146,1.6055,1.4909,0.1067,0.759,0.6523,0.1016,0.2136,0.112,0.1349,0.1484,0.0135,0.0932,0.3515,0.2583,0.1338,0.3509,0.2171,0.0742
# s002,1,2,0.1111,0.3451,0.234,0.0694,0.1283,0.0589,0.0908,0.1357,0.0449,0.0829,1.197,1.1141,0.0689,0.7822,0.7133,0.157,0.7877,0.6307,0.1066,0.1684,0.0618,0.1412,0.2558,0.1146,0.1146,0.2642,0.1496,0.0839,0.2756,0.1917,0.0747
# s002,1,3,0.1328,0.2072,0.0744,0.0731,0.1291,0.056,0.0821,0.1542,0.0721,0.0808,1.0408,0.96,0.0892,0.6203,0.5311,0.1454,0.7195,0.5741,0.1365,0.2931,0.1566,0.1621,0.2332,0.0711,0.1172,0.2705,0.1533,0.1085,0.2847,0.1762,0.0945
# ...

# %%
from google.colab import files

# Download the combined CSV file
files.download("combined_keystroke_data.csv")

# %%
import pandas as pd

# Load from local file
df = pd.read_csv("combined_keystroke_data.csv")

# If working on AWS SageMaker, use:
# df = pd.read_csv("s3://your-bucket/combined_keystroke_data.csv")

# %%
#### **C. Model Training & Testing**
Split the data into **genuine** (original users) and **imposters** (synthetic users):
```python
genuine_data = df[df["subject"].str.startswith("s0")]  # Adjust based on real user IDs
imposter_data = df[~df["subject"].str.startswith("s0")]

# Train/test split
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
  genuine_data.drop("subject", axis=1), genuine_data["subject"], test_size=0.2
)
# Out:
#   File "<ipython-input-9-95be2cccdc7c>", line 2
#     Split the data into **genuine** (original users) and **imposters** (synthetic users):
#           ^
# SyntaxError: invalid syntax

# %%
genuine_data = df[df["subject"].str.startswith("s0")]  # Adjust based on real user IDs
imposter_data = df[~df["subject"].str.startswith("s0")]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
  genuine_data.drop("subject", axis=1), genuine_data["subject"], test_size=0.2
)

# %%
import boto3

s3 = boto3.client("s3")
s3.upload_file("combined_keystroke_data.csv", "your-bucket-name", "combined_keystroke_data.csv")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-12-13842c2bf484> in <cell line: 0>()
# ----> 1 import boto3
#       2
#       3 s3 = boto3.client("s3")
#       4 s3.upload_file("combined_keystroke_data.csv", "your-bucket-name", "combined_keystroke_data.csv")
#
# ModuleNotFoundError: No module named 'boto3'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
import boto3

s3 = boto3.client("s3")
s3.upload_file("combined_keystroke_data.csv", "your-bucket-name", "combined_keystroke_data.csv")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-13-13842c2bf484> in <cell line: 0>()
# ----> 1 import boto3
#       2
#       3 s3 = boto3.client("s3")
#       4 s3.upload_file("combined_keystroke_data.csv", "your-bucket-name", "combined_keystroke_data.csv")
#
# ModuleNotFoundError: No module named 'boto3'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
